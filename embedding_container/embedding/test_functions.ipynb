# %%
# !pip install torch==1.4.0+cpu torchvision==0.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#   Using cached Pillow-7.1.2-cp37-cp37m-win_amd64.whl (2.0 MB)
# ...
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'f:\software\python\python.exe -m pip install --upgrade pip' command.

# %%
# !python download_pretrained_models.py -m distilbert-base-nli-stsb-mean-tokens
# Out:
# Namespace(location='pretrained_models', models=['distilbert-base-nli-stsb-mean-tokens'])
#   0%|          | 0.00/245M [00:00<?, ?B/s]
#   0%|          | 16.4k/245M [00:00<38:17, 106kB/s]
#   0%|          | 49.2k/245M [00:00<33:41, 121kB/s]
#   0%|          | 81.9k/245M [00:00<30:11, 135kB/s]
#   0%|          | 115k/245M [00:00<27:36, 148kB/s]
#   0%|          | 180k/245M [00:00<22:38, 180kB/s]
#   0%|          | 246k/245M [00:01<19:08, 213kB/s]
#   0%|          | 360k/245M [00:01<15:17, 266kB/s]
#   0%|          | 475k/245M [00:01<12:32, 324kB/s]
#   0%|          | 606k/245M [00:01<10:24, 390kB/s]
#   0%|          | 836k/245M [00:01<08:16, 491kB/s]
#   0%|          | 1.15M/245M [00:01<06:28, 627kB/s]
#   1%|          | 1.54M/245M [00:02<05:02, 803kB/s]
#   1%|          | 2.03M/245M [00:02<03:57, 1.02MB/s]
#   1%|1         | 2.54M/245M [00:02<03:11, 1.26MB/s]
#   1%|1         | 3.05M/245M [00:02<02:28, 1.63MB/s]
#   1%|1         | 3.35M/245M [00:02<02:13, 1.81MB/s]
# ...

# %%
# !python --version
# Out:
# Python 3.7.7

# %%
# !pip uninstall pillow
# Out:
# ^C

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('pretrained_models/distilbert_base_nli_stsb_mean_tokens',device="cpu")

# %%
model.encode(["The fox jumped over the lazy donkey"])
# Out:
# [array([-2.49183312e-01, -1.96049452e-01, -8.94136429e-01,  2.74480313e-01,
#          8.08761194e-02,  4.34267163e-01, -2.99877048e-01,  3.19920317e-03,
#         -7.45281637e-01,  8.19386244e-02, -3.30557637e-02, -3.60987112e-02,
#         -2.17263266e-01, -1.03795671e+00, -7.12665081e-01, -1.00912452e+00,
#         -2.48578101e-01, -2.82043487e-01,  3.01156908e-01, -4.87427175e-01,
#          3.69170398e-01,  1.04657985e-01, -8.22555602e-01, -3.14863503e-01,
#         -7.96269774e-01, -1.81264102e-01, -6.86908960e-01,  2.18804136e-01,
#          2.46876553e-01, -4.75754380e-01, -4.14939016e-01,  2.45586023e-01,
#          7.83140957e-01,  9.83155146e-02,  1.59821808e-01,  3.13382685e-01,
#         -1.96269989e-01, -5.74899137e-01,  1.40657797e-01, -6.10843122e-01,
#          3.66942406e-01,  1.72806866e-02,  3.80831242e-01,  2.20805705e-01,
#         -5.81625760e-01,  6.87629953e-02, -8.32799971e-01, -7.96973467e-01,
# ...
